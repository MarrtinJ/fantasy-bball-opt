# %% [markdown]
# # Installing/Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/dataset2.csv')
df = df[['Date', 'Name', 'Team', 'Position', 'Salary', 'FPTS']]
df.shape
# Out:
# (43482, 6)

# %%
# all the unique dates in the dataset
dates = df['Date'].unique()
dates.shape
# Out:
# (356,)

# %%
# starting with just a single date

for date in dates:
    df = df[df['Date']==date]
    Utils = df.copy()
    Utils['Position'] = 'UTIL'
    
    multPositions = df[df['Position'].str.contains("/")]
    multPositions.reset_index(inplace=True, drop=True)

    pos1 = []
    pos2 = []
    for index, row in multPositions.iterrows():
      playerPos1, playerPos2 = row['Position'].split('/')
      copy1 = row.copy()
      copy1['Position'] = playerPos1
      copy2 = row.copy()
      copy2['Position'] = playerPos2
      # print(copy)
      pos1.append(copy1)
      pos2.append(copy2)
      # print(playerPos1, playerPos2)

    print(multPositions.shape)
    pos1 = pd.DataFrame(pos1)
    pos2 = pd.DataFrame(pos2)

# %% [markdown]
# # Creating DFs for each position

# %%
# Out:
# (164, 6)

# %%
print(pos1.shape)
pos1
# Out:
# (164, 6)
#          Date              Name Team Position  Salary   FPTS
# 0    20191023  Donovan Mitchell  Uta       PG    7800  55.00
# 1    20191023       Luka Doncic  Dal       PG    9400  52.75
# 2    20191023   Justise Winslow  Mia       PG    5800  49.25
# 3    20191023   Malcolm Brogdon  Ind       PG    6500  45.75
# 4    20191023       Ben Simmons  Phi       PG    8500  45.50
# ..        ...               ...  ...      ...     ...    ...
# 159  20191023    Meyers Leonard  Mia       PF    3100   5.75
# 160  20191023    Caleb Swanigan  Sac       PF    3000   5.00
# 161  20191023       Luke Kornet  Chi       PF    3300   4.50
# 162  20191023     Cheick Diallo  Pho       PF    3400   2.00
# 163  20191023    Christian Wood  Det       PF    4800  -0.50
#
# [164 rows x 6 columns]

# %%
print(pos2.shape)
pos2
# Out:
# (164, 6)
#          Date              Name Team Position  Salary   FPTS
# 0    20191023  Donovan Mitchell  Uta       SG    7800  55.00
# 1    20191023       Luka Doncic  Dal       SG    9400  52.75
# 2    20191023   Justise Winslow  Mia       SF    5800  49.25
# 3    20191023   Malcolm Brogdon  Ind       SG    6500  45.75
# 4    20191023       Ben Simmons  Phi       SF    8500  45.50
# ..        ...               ...  ...      ...     ...    ...
# 159  20191023    Meyers Leonard  Mia        C    3100   5.75
# 160  20191023    Caleb Swanigan  Sac        C    3000   5.00
# 161  20191023       Luke Kornet  Chi        C    3300   4.50
# 162  20191023     Cheick Diallo  Pho        C    3400   2.00
# 163  20191023    Christian Wood  Det        C    4800  -0.50
#
# [164 rows x 6 columns]

# %%
onePosition = df[ df['Position'].str.contains('/')==False ]
print(onePosition.shape)
onePosition
# Out:
# (52, 6)
#          Date                     Name Team Position  Salary   FPTS
# 32   20191023           Damian Lillard  Por       PG    9100  51.00
# 36   20191023             Bradley Beal  Was       SG    8800  45.50
# 39   20191023              Ricky Rubio  Pho       PG    5800  42.50
# 40   20191023          Dejounte Murray  SAS       PG    5600  41.50
# 41   20191023               Chris Paul  OKC       PG    7400  40.00
# 43   20191023            Elfrid Payton  NYK       PG    4800  36.00
# 48   20191023             Goran Dragic  Mia       PG    5100  32.25
# 52   20191023               Tyus Jones  Mem       PG    4000  29.75
# 53   20191023              Tyler Herro  Mia       SG    4800  29.50
# 55   20191023                Ja Morant  Mem       PG    6600  26.00
# 57   20191023              Jeff Teague  Min       PG    5600  24.25
# 58   20191023          Emmanuel Mudiay  Uta       PG    4000  24.00
# 64   20191023              DJ Augustin  Orl       PG    5000  20.75
# 67   20191023             Terry Rozier  Cha       PG    7300  20.00
# 71   20191023           Darius Garland  Cle       PG    4400  19.50
# 72   20191023            Chris Chiozza  Was       PG    3000  18.25
# 75   20191023             Kemba Walker  Bos       PG    8100  16.50
# 79   20191023              DeAaron Fox  Sac       PG    7700  14.25
# 83   20191023             TJ McConnell  Ind       PG    3100  13.75
# 84   20191023              Gary Harris  Den       SG    4800  13.75
# 85   20191023              Mike Conley  Uta       PG    7500  13.50
# 90   20191023             Monte Morris  Den       PG    3300  11.25
# 95   20191023  Michael Carter-Williams  Orl       PG    3300   7.25
# 98   20191023           Carsen Edwards  Bos       PG    3500   4.75
# 101  20191023          Dennis Smith Jr  NYK       PG    5400   3.50
# 105  20191023              Tim Frazier  Det       PG    3000   0.00
# 106  20191023             Jared Harper  Pho       PG    3000   0.00
# 107  20191023              Daryl Macon  Mia       PG    3000   0.00
# 108  20191023                Raul Neto  Phi       PG    3000   0.00
# 109  20191023          Justin Robinson  Was       PG    3000   0.00
# 122  20191023            Rui Hachimura  Was       PF    4900  28.00
# 134  20191023             Royce ONeale  Uta       SF    3300  22.75
# 139  20191023               Trey Lyles  SAS       PF    3200  21.25
# 143  20191023              Chris Silva  Mia       PF    3000  20.50
# 150  20191023          Nemanja Bjelica  Sac       PF    4000  17.00
# 191  20191023           Andre Drummond  Det        C    8400  78.25
# 192  20191023       Karl-Anthony Towns  Min        C   10100  73.50
# 196  20191023             Myles Turner  Ind        C    6300  46.25
# 197  20191023              Joel Embiid  Phi        C    9800  43.75
# 198  20191023         Hassan Whiteside  Por        C    7000  43.25
# 199  20191023            Deandre Ayton  Pho        C    8000  43.25
# 201  20191023             Nikola Jokic  Den        C    9600  40.25
# 203  20191023           Nikola Vucevic  Orl        C    8600  38.75
# 206  20191023         Tristan Thompson  Cle        C    5700  34.25
# 208  20191023              Cody Zeller  Cha        C    4700  32.50
# 214  20191023              Rudy Gobert  Uta        C    8300  24.50
# 217  20191023             Steven Adams  OKC        C    6700  20.75
# 226  20191023             Jakob Poeltl  SAS        C    3900  14.50
# 230  20191023           Dewayne Dedmon  Sac        C    5100  13.00
# 231  20191023        Jonas Valanciunas  Mem        C    6600  12.25
# 235  20191023              Aron Baynes  Pho        C    3400   8.50
# 238  20191023             Nerlens Noel  OKC        C    3200   6.50

# %%
currentPlayers = pd.concat([onePosition, pos1, pos2], ignore_index=True)
currentPlayers.sort_values(['Name', 'Team', 'Position'], na_position='first', inplace=True, ignore_index=True)

# %%
Gs = currentPlayers[currentPlayers['Position'].isin(['PG', 'SG'])]
Gs.drop_duplicates(subset='Name', inplace=True)
Gs.reset_index(inplace=True, drop=True)
Gs['Position'] = 'G'
Gs
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#          Date             Name Team Position  Salary   FPTS
# 0    20191023    Aaron Holiday  Ind        G    3400   5.75
# 1    20191023    Allonzo Trier  NYK        G    3600  -0.50
# 2    20191023   Andrew Wiggins  Min        G    5700  30.50
# 3    20191023  Anfernee Simons  Por        G    3800   8.50
# 4    20191023      Ben Simmons  Phi        G    8500  45.50
# ..        ...              ...  ...      ...     ...    ...
# 111  20191023       Tyus Jones  Mem        G    4000  29.75
# 112  20191023  Wayne Ellington  NYK        G    3500   7.25
# 113  20191023      Will Barton  Den        G    4300  34.75
# 114  20191023     Yogi Ferrell  Sac        G    3000   4.75
# 115  20191023      Zach LaVine  Chi        G    7900  38.00
#
# [116 rows x 6 columns]

# %%
Fs = currentPlayers[currentPlayers['Position'].isin(['SF', 'PF'])]
Fs.drop_duplicates(subset='Name', inplace=True)
Fs.reset_index(inplace=True, drop=True)
Fs['Position'] = 'F'
Fs
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#          Date               Name Team Position  Salary   FPTS
# 0    20191023       Aaron Gordon  Orl        F    6400  22.00
# 1    20191023  Admiral Schofield  Was        F    3300   1.50
# 2    20191023         Al Horford  Phi        F    5600  25.00
# 3    20191023    Al-Farouq Aminu  Orl        F    4000  15.75
# 4    20191023     Andrew Wiggins  Min        F    5700  30.50
# ..        ...                ...  ...      ...     ...    ...
# 118  20191023    Wayne Ellington  NYK        F    3500   7.25
# 119  20191023  Wendell Carter Jr  Chi        F    5600  24.75
# 120  20191023     Wenyen Gabriel  Sac        F    3000   1.75
# 121  20191023        Will Barton  Den        F    4300  34.75
# 122  20191023       Zach Collins  Por        F    5400  17.25
#
# [123 rows x 6 columns]

# %%
currentPlayers = pd.concat([currentPlayers, Gs, Fs, Utils], ignore_index=True)
currentPlayers.sort_values(['Name', 'Team', 'Position'], na_position='first', inplace=True, ignore_index=True)

# %%
currentPlayers
# Out:
#          Date           Name Team Position  Salary   FPTS
# 0    20191023   Aaron Gordon  Orl        F    6400  22.00
# 1    20191023   Aaron Gordon  Orl       PF    6400  22.00
# 2    20191023   Aaron Gordon  Orl       SF    6400  22.00
# 3    20191023   Aaron Gordon  Orl     UTIL    6400  22.00
# 4    20191023  Aaron Holiday  Ind        G    3400   5.75
# ..        ...            ...  ...      ...     ...    ...
# 830  20191023   Zach Collins  Por     UTIL    5400  17.25
# 831  20191023    Zach LaVine  Chi        G    7900  38.00
# 832  20191023    Zach LaVine  Chi       PG    7900  38.00
# 833  20191023    Zach LaVine  Chi       SG    7900  38.00
# 834  20191023    Zach LaVine  Chi     UTIL    7900  38.00
#
# [835 rows x 6 columns]

# %% [markdown]
# # DFS Setup / Helper Functions

# %%
# incr determines if the players are each position are sorted by increasing salary
incr = True

PGs = currentPlayers[currentPlayers['Position'] == 'PG']
PGs.sort_values(by=['Salary'], ascending=incr, inplace=True)

SGs = currentPlayers[currentPlayers['Position'] == 'SG']
SGs.sort_values(by=['Salary'], ascending=incr, inplace=True)

SFs = currentPlayers[currentPlayers['Position'] == 'SF']
SFs.sort_values(by=['Salary'], ascending=incr, inplace=True)

PFs = currentPlayers[currentPlayers['Position'] == 'PF']
PFs.sort_values(by=['Salary'], ascending=incr, inplace=True)

Cs = currentPlayers[currentPlayers['Position'] == 'C']
Cs.sort_values(by=['Salary'], ascending=incr, inplace=True)

Gs = currentPlayers[currentPlayers['Position'] == 'G']
Gs.sort_values(by=['Salary'], ascending=incr, inplace=True)

Fs = currentPlayers[currentPlayers['Position'] == 'F']
Fs.sort_values(by=['Salary'], ascending=incr, inplace=True)

Utils = currentPlayers[currentPlayers['Position'] == 'UTIL']
Utils.sort_values(by=['Salary'], ascending=incr, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
# minPrices holds the minimum budget required to keep searching at each position
#   where the number at index i represents the sum of the least expensive players at position index >= i

# maxPrices holds the minimum budget required to afford the highest scoring players in the remaining positions
#   where the number at index i represents the sum of the most expensive players at position index >= i

l1 = [PGs, SGs, SFs, PFs, Cs, Gs, Fs, Utils]

minSalaries = []
maxSalaries = []
l2 = []
position_order = []

l3 = []

for i in range(8):
  # could also consider sorting by the mean salary of each position
  pos_max = l1[i].Salary.max()
  l2.append((pos_max, l1[i]))

# sort the positions in descending order by max salary
l2 = sorted(l2, key=lambda x: x[0], reverse=True)

cheapest_sum = 0
expensive_sum = 0
for i in range(len(l2)):
  # keeping track of the sum of salaries for the most expensive players in each position
  pos_max = l2[i][0]
  expensive_sum += pos_max
  maxSalaries.insert(0, expensive_sum)

  # removing the max sal info, retaining just the dataframe
  l2[i] = l2[i][1]

  l3.append(l2[i].sort_values(by=['FPTS'], ascending=False))

  # keeping track of the sum of salaries for the least expensive players in each position
  pos_min = l2[i].Salary.min()
  cheapest_sum += pos_min
  minSalaries.insert(0, cheapest_sum)

  # keeping track of the sorted order of the positions
  pos = l2[i]['Position'].iloc[0]
  position_order.append(pos)

  print(pos, pos_min, pos_max)

# l2
# position_order
# maxSalaries
# minSalaries
l3
# Out:
# C 3000 10100
# UTIL 3000 10100
# PG 3000 9400
# SG 3000 9400
# G 3000 9400
# SF 3000 8500
# F 3000 8500
# PF 3000 8200
# [         Date                Name Team Position  Salary   FPTS
#  24   20191023      Andre Drummond  Det        C    8400  78.25
#  446  20191023  Karl-Anthony Towns  Min        C   10100  73.50
#  496  20191023     Lauri Markkanen  Chi        C    7800  62.75
#  420  20191023       Julius Randle  NYK        C    7800  55.25
#  226  20191023    Domantas Sabonis  Ind        C    6900  46.75
#  610  20191023        Myles Turner  Ind        C    6300  46.25
#  394  20191023         Joel Embiid  Phi        C    9800  43.75
#  187  20191023       Deandre Ayton  Pho        C    8000  43.25
#  325  20191023    Hassan Whiteside  Por        C    7000  43.25
#  468  20191023          Kevin Love  Cle        C    7600  40.50
#  622  20191023        Nikola Jokic  Den        C    9600  40.25
#  630  20191023       PJ Washington  Cha        C    5500  39.00
#  624  20191023      Nikola Vucevic  Orl        C    8600  38.75
#  488  20191023   LaMarcus Aldridge  SAS        C    7300  36.00
#  476  20191023  Kristaps Porzingis  Dal        C    8200  34.50
#  793  20191023    Tristan Thompson  Cle        C    5700  34.25
#  41   20191023         Bam Adebayo  Mia        C    7000  33.25
#  128  20191023         Cody Zeller  Cha        C    4700  32.50
#  747  20191023       Thomas Bryant  Was        C    6600  32.25
#  638  20191023        Paul Millsap  Den        C    4900  30.75
#  50   20191023        Bobby Portis  NYK        C    5500  27.75
#  12   20191023          Al Horford  Phi        C    5600  25.00
#  810  20191023   Wendell Carter Jr  Chi        C    5600  24.75
#  680  20191023         Rudy Gobert  Uta        C    8300  24.50
#  448  20191023        Kelly Olynyk  Mia        C    4600  22.50
#  70   20191023      Brandon Clarke  Mem        C    3800  20.75
#  713  20191023        Steven Adams  OKC        C    6700  20.75
#  559  20191023       Mason Plumlee  Den        C    3400  19.50
#  546  20191023     Markieff Morris  Det        C    3600  17.50
#  827  20191023        Zach Collins  Por        C    5400  17.25
#  276  20191023      Frank Kaminsky  Pho        C    3500  17.00
#  572  20191023         Maxi Kleber  Dal        C    4200  16.00
#  709  20191023     Skal Labissiere  Por        C    3000  16.00
#  591  20191023        Mike Muscala  OKC        C    3000  15.50
#  343  20191023        Jakob Poeltl  SAS        C    3900  14.50
#  606  20191023       Moritz Wagner  Was        C    3400  14.50
#  664  20191023     Robert Williams  Bos        C    3400  14.25
#  377  20191023        Jerami Grant  Den        C    4800  13.50
#  252  20191023            Ed Davis  Uta        C    3400  13.00
#  219  20191023      Dewayne Dedmon  Sac        C    5100  13.00
#  396  20191023   Jonas Valanciunas  Mem        C    6600  12.25
#  626  20191023         Noah Vonleh  Min        C    3400  12.00
#  653  20191023      Richaun Holmes  Sac        C    3700   8.75
#  751  20191023          Thon Maker  Det        C    3800   8.50
#  39   20191023         Aron Baynes  Pho        C    3400   8.50
#  79   20191023       Bruno Caboclo  Mem        C    3200   7.25
#  484  20191023         Kyle OQuinn  Phi        C    3200   6.75
#  615  20191023        Nerlens Noel  OKC        C    3200   6.50
#  149  20191023        Daniel Theis  Bos        C    3400   6.25
#  726  20191023          Taj Gibson  NYK        C    4000   6.00
#  576  20191023      Meyers Leonard  Mia        C    3100   5.75
#  96   20191023      Caleb Swanigan  Sac        C    3000   5.00
#  509  20191023         Luke Kornet  Chi        C    3300   4.50
#  107  20191023       Cheick Diallo  Pho        C    3400   2.00
#  120  20191023      Christian Wood  Det        C    4800  -0.50,
#           Date                Name Team Position  Salary   FPTS
#  25   20191023      Andre Drummond  Det     UTIL    8400  78.25
#  447  20191023  Karl-Anthony Towns  Min     UTIL   10100  73.50
#  499  20191023     Lauri Markkanen  Chi     UTIL    7800  62.75
#  423  20191023       Julius Randle  NYK     UTIL    7800  55.25
#  233  20191023    Donovan Mitchell  Uta     UTIL    7800  55.00
#  ..        ...                 ...  ...      ...     ...    ...
#  436  20191023     Justin Robinson  Was     UTIL    3000   0.00
#  170  20191023         Daryl Macon  Mia     UTIL    3000   0.00
#  38   20191023    Anthony Tolliver  Por     UTIL    3100  -0.50
#  123  20191023      Christian Wood  Det     UTIL    4800  -0.50
#  23   20191023       Allonzo Trier  NYK     UTIL    3600  -0.50
#
#  [216 rows x 6 columns],
#           Date              Name Team Position  Salary   FPTS
#  231  20191023  Donovan Mitchell  Uta       PG    7800  55.00
#  501  20191023       Luka Doncic  Dal       PG    9400  52.75
#  147  20191023    Damian Lillard  Por       PG    9100  51.00
#  439  20191023   Justise Winslow  Mia       PG    5800  49.25
#  514  20191023   Malcolm Brogdon  Ind       PG    6500  45.75
#  ..        ...               ...  ...      ...     ...    ...
#  756  20191023       Tim Frazier  Det       PG    3000   0.00
#  169  20191023       Daryl Macon  Mia       PG    3000   0.00
#  435  20191023   Justin Robinson  Was       PG    3000   0.00
#  354  20191023      Jared Harper  Pho       PG    3000   0.00
#  21   20191023     Allonzo Trier  NYK       PG    3600  -0.50
#
#  [78 rows x 6 columns],
#           Date              Name Team Position  Salary   FPTS
#  232  20191023  Donovan Mitchell  Uta       SG    7800  55.00
#  502  20191023       Luka Doncic  Dal       SG    9400  52.75
#  515  20191023   Malcolm Brogdon  Ind       SG    6500  45.75
#  68   20191023      Bradley Beal  Was       SG    8800  45.50
#  213  20191023      Devin Booker  Pho       SG    8700  42.50
#  ..        ...               ...  ...      ...     ...    ...
#  707  20191023      Shake Milton  Phi       SG    3000   1.50
#  65   20191023    Brad Wanamaker  Bos       SG    3000   1.50
#  292  20191023  Garrison Mathews  Was       SG    3000   1.50
#  282  20191023   Frank Ntilikina  NYK       SG    3000   1.00
#  22   20191023     Allonzo Trier  NYK       SG    3600  -0.50
#
#  [84 rows x 6 columns],
#           Date              Name Team Position  Salary   FPTS
#  230  20191023  Donovan Mitchell  Uta        G    7800  55.00
#  500  20191023       Luka Doncic  Dal        G    9400  52.75
#  146  20191023    Damian Lillard  Por        G    9100  51.00
#  438  20191023   Justise Winslow  Mia        G    5800  49.25
#  513  20191023   Malcolm Brogdon  Ind        G    6500  45.75
#  ..        ...               ...  ...      ...     ...    ...
#  353  20191023      Jared Harper  Pho        G    3000   0.00
#  168  20191023       Daryl Macon  Mia        G    3000   0.00
#  434  20191023   Justin Robinson  Was        G    3000   0.00
#  755  20191023       Tim Frazier  Det        G    3000   0.00
#  20   20191023     Allonzo Trier  NYK        G    3600  -0.50
#
#  [116 rows x 6 columns],
#           Date              Name Team Position  Salary   FPTS
#  440  20191023   Justise Winslow  Mia       SF    5800  49.25
#  48   20191023       Ben Simmons  Phi       SF    8500  45.50
#  765  20191023     Tobias Harris  Phi       SF    6700  44.25
#  368  20191023      Jayson Tatum  Bos       SF    6300  42.00
#  532  20191023     Marcus Morris  NYK       SF    5100  39.50
#  ..        ...               ...  ...      ...     ...    ...
#  691  20191023      Semi Ojeleye  Bos       SF    3000   1.25
#  310  20191023    Grant Williams  Bos       SF    3300   1.25
#  717  20191023           TJ Leaf  Ind       SF    3300   1.25
#  444  20191023         KZ Okpala  Mia       SF    3000   0.75
#  37   20191023  Anthony Tolliver  Por       SF    3100  -0.50
#
#  [81 rows x 6 columns],
#           Date              Name Team Position  Salary   FPTS
#  497  20191023   Lauri Markkanen  Chi        F    7800  62.75
#  421  20191023     Julius Randle  NYK        F    7800  55.25
#  437  20191023   Justise Winslow  Mia        F    5800  49.25
#  227  20191023  Domantas Sabonis  Ind        F    6900  46.75
#  45   20191023       Ben Simmons  Phi        F    8500  45.50
#  ..        ...               ...  ...      ...     ...    ...
#  297  20191023     Georges Niang  Uta        F    3000   1.25
#  715  20191023           TJ Leaf  Ind        F    3300   1.25
#  442  20191023         KZ Okpala  Mia        F    3000   0.75
#  121  20191023    Christian Wood  Det        F    4800  -0.50
#  35   20191023  Anthony Tolliver  Por        F    3100  -0.50
#
#  [123 rows x 6 columns],
#           Date              Name Team Position  Salary   FPTS
#  498  20191023   Lauri Markkanen  Chi       PF    7800  62.75
#  422  20191023     Julius Randle  NYK       PF    7800  55.25
#  228  20191023  Domantas Sabonis  Ind       PF    6900  46.75
#  764  20191023     Tobias Harris  Phi       PF    6700  44.25
#  367  20191023      Jayson Tatum  Bos       PF    6300  42.00
#  ..        ...               ...  ...      ...     ...    ...
#  690  20191023      Semi Ojeleye  Bos       PF    3000   1.25
#  298  20191023     Georges Niang  Uta       PF    3000   1.25
#  443  20191023         KZ Okpala  Mia       PF    3000   0.75
#  122  20191023    Christian Wood  Det       PF    4800  -0.50
#  36   20191023  Anthony Tolliver  Por       PF    3100  -0.50
#
#  [82 rows x 6 columns]]

# %%
# players[i][j] represents the ith player in the jth position
# players[i] sorted in ascending order by salary

players = []

for i in range(len(l2)):
  players_list = l2[i]['Name'].to_list()
  # print(position_order[i], players_list)
  players.append(players_list)

# players

# %%
def getSingleScore(player):
  return currentPlayers[currentPlayers['Name'] == player].iloc[0].FPTS

def getSingleSalary(player):
  return currentPlayers[currentPlayers['Name'] == player].iloc[0].Salary

# %%
# getScore takes in a dict of players, returns the fantasy points scored by players
def getScore(players):
  total_score = 0
  for player in players.values():
    player_score = getSingleScore(player)
    # print(player, player_score)
    total_score += player_score
  return total_score

# %% [markdown]
# # Inverted DFS

# %%
MAX_POSITION_INDEX = 7

# invertedDFS(players, 0, 0, 50000)
def invertedDFS(players, pos_index, player_index, budget):
  player = players[pos_index][player_index]

  salary = getSingleSalary(player)
  newBudget = budget - salary

  # optimization 1: instead of comparing with 0, compare with sum(min_budget of each remaining position)
  #   can be computed ahead of time for each level
  # if newBudget < 0:
  if pos_index < MAX_POSITION_INDEX and newBudget < minSalaries[pos_index+1]:
    print('out of budget at position {}'.format(pos_index))
    return dict(), np.NINF

  # optimization 3: two separate cases: if I have enough budget to pick the max salary from every remaining level, no need for recursion, just pick best score from every lower level
  # otherwise, do the recursive search in the next block
  if pos_index < MAX_POSITION_INDEX and newBudget > maxSalaries[pos_index+1]:
    print('can afford best players at position {}'.format(pos_index))

    assignment = dict()
    assignment[pos_index] = player
    for i in range(pos_index+1, 8):
      for index, row in l3[i].iterrows():
        if row['Name'] not in assignment.values():
          assignment[i] = row['Name']
          break
    # print(assignment, getScore(assignment))
    return assignment, getScore(assignment)

  if pos_index == MAX_POSITION_INDEX:
    assignment = {pos_index: player}
    # print(pos_index, player_index, player)
    return assignment, getScore(assignment)
  else:
    max_score = 0
    best_lineup = dict()
    for j in range(len(players[pos_index + 1])):
      a, s = invertedDFS(players, pos_index+1, j, newBudget) 
      # optimization 2: if a returns None (a is empty), break out of the current loop
      if not a:
        print('next level returned none')
        break
      if s > max_score and a and player not in a.values(): #duplicate check
        max_score = s
        best_lineup = a
        # print(max_score, best_lineup)
    if best_lineup:
      best_lineup[pos_index]=player
      return best_lineup, max_score + getSingleScore(player)
    else:
      return dict(), np.NINF

# %%
invertedDFS(players, 0, 0, 50000)
# Out:
# Streaming output truncated to the last 5000 lines.
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# ...
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# can afford best players at position 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-65a1bd13c93f> in <module>()
# ----> 1 invertedDFS(players, 0, 0, 50000)
#
# <ipython-input-40-60b9de551574> in invertedDFS(players, pos_index, player_index, budget)
#      38     best_lineup = dict()
#      39     for j in range(len(players[pos_index + 1])):
# ---> 40       a, s = invertedDFS(players, pos_index+1, j, newBudget)
#      41       # optimization 2: if a returns None (a is empty), break out of the current loop
#      42       if not a:
#
# <ipython-input-40-60b9de551574> in invertedDFS(players, pos_index, player_index, budget)
#      38     best_lineup = dict()
#      39     for j in range(len(players[pos_index + 1])):
# ---> 40       a, s = invertedDFS(players, pos_index+1, j, newBudget)
#      41       # optimization 2: if a returns None (a is empty), break out of the current loop
#      42       if not a:
#
# <ipython-input-40-60b9de551574> in invertedDFS(players, pos_index, player_index, budget)
#      38     best_lineup = dict()
#      39     for j in range(len(players[pos_index + 1])):
# ---> 40       a, s = invertedDFS(players, pos_index+1, j, newBudget)
#      41       # optimization 2: if a returns None (a is empty), break out of the current loop
#      42       if not a:
#
# <ipython-input-40-60b9de551574> in invertedDFS(players, pos_index, player_index, budget)
#      38     best_lineup = dict()
#      39     for j in range(len(players[pos_index + 1])):
# ---> 40       a, s = invertedDFS(players, pos_index+1, j, newBudget)
#      41       # optimization 2: if a returns None (a is empty), break out of the current loop
#      42       if not a:
#
# <ipython-input-40-60b9de551574> in invertedDFS(players, pos_index, player_index, budget)
#      38     best_lineup = dict()
#      39     for j in range(len(players[pos_index + 1])):
# ---> 40       a, s = invertedDFS(players, pos_index+1, j, newBudget)
#      41       # optimization 2: if a returns None (a is empty), break out of the current loop
#      42       if not a:
#
# <ipython-input-40-60b9de551574> in invertedDFS(players, pos_index, player_index, budget)
#      38     best_lineup = dict()
#      39     for j in range(len(players[pos_index + 1])):
# ---> 40       a, s = invertedDFS(players, pos_index+1, j, newBudget)
#      41       # optimization 2: if a returns None (a is empty), break out of the current loop
#      42       if not a:
#
# <ipython-input-40-60b9de551574> in invertedDFS(players, pos_index, player_index, budget)
#      28           break
#      29     # print(assignment, getScore(assignment))
# ---> 30     return assignment, getScore(assignment)
#      31
#      32   if pos_index == MAX_POSITION_INDEX:
#
# <ipython-input-39-7a410ce8741f> in getScore(players)
#       3   total_score = 0
#       4   for player in players.values():
# ----> 5     player_score = getSingleScore(player)
#       6     # print(player, player_score)
#       7     total_score += player_score
#
# <ipython-input-38-4fe89fbacaa0> in getSingleScore(player)
#       1 def getSingleScore(player):
# ----> 2   return currentPlayers[currentPlayers['Name'] == player].iloc[0].FPTS
#       3
#       4 def getSingleSalary(player):
#       5   return currentPlayers[currentPlayers['Name'] == player].iloc[0].Salary
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1566             self._validate_integer(key, axis)
#    1567
# -> 1568             return self.obj._ixs(key, axis=axis)
#    1569
#    1570     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    3377         # irow
#    3378         if axis == 0:
# -> 3379             new_values = self._mgr.fast_xs(i)
#    3380
#    3381             # if we are a copy, mark as such
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in fast_xs(self, loc)
#     962             result = np.empty(n, dtype=dtype)
#     963
# --> 964         result = ensure_wrapped_if_datetimelike(result)
#     965
#     966         for blk in self.blocks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Test

# %%
res = ({0: 'Nicolo Melli',
  1: 'Anthony Davis',
  2: 'Josh Hart',
  3: 'Maurice Harkless',
  4: 'Nickeil Alexander-Walker',
  5: 'Kawhi Leonard',
  6: 'LeBron James',
  7: 'Danny Green'}, 289.75)
res
# Out:
# ({0: 'Nicolo Melli',
#   1: 'Anthony Davis',
#   2: 'Josh Hart',
#   3: 'Maurice Harkless',
#   4: 'Nickeil Alexander-Walker',
#   5: 'Kawhi Leonard',
#   6: 'LeBron James',
#   7: 'Danny Green'},
#  289.75)

# %%
soln = res[0]
soln['Date'] = date
soln['FPTS'] = res[1]
# Out:
# {0: 'Nicolo Melli',
#  1: 'Anthony Davis',
#  2: 'Josh Hart',
#  3: 'Maurice Harkless',
#  4: 'Nickeil Alexander-Walker',
#  5: 'Kawhi Leonard',
#  6: 'LeBron James',
#  7: 'Danny Green',
#  'Date': 20191023,
#  'FPTS': 289.75}

# %%
soln_df = pd.DataFrame(soln, index=[0])
soln_df
# Out:
#               0              1          2                 3  \
# 0  Nicolo Melli  Anthony Davis  Josh Hart  Maurice Harkless
#
#                           4              5             6            7    FPTS  \
# 0  Nickeil Alexander-Walker  Kawhi Leonard  LeBron James  Danny Green  289.75
#
#        Date
# 0  20191023
