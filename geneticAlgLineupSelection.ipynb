# %% [markdown]
# Generates a lineup using a genetic algorithm, using the known scores of the players (oracle solution)
# Could also be extended to create lineups based of any heuristic

# %% [markdown]
# # Installing/Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd

import random

# %%
# stop the pandas indexing/splicing warning from appearing
import warnings
warnings.filterwarnings('ignore')

# %%
# for oracle

param = 'FPTS'

df = pd.read_csv('/content/dataset2_splitpositions_minutesfixed.csv')
df = df[['Date', 'Name', 'Position', 'Salary', param]]
# df = df[df.FPTS >= 0] # drop all players who scored less than 0 points
df.dropna(subset=[param], inplace=True)
df.shape
# Out:
# (155418, 5)

# %%
# for salary heuristic

param = 'Prediction'

df = pd.read_csv('/content/2020-21_predictionsUsingSalary.csv')
df = df[['Date', 'Name', 'Position', 'Salary', 'FPTS', param]]
# df = df[df.FPTS >= 0] # drop all players who scored less than 0 points
df.dropna(subset=[param], inplace=True)
df.shape
# Out:
# (76697, 6)

# %%
# for rolling avg heuristic

param = 'Pred1'

df = pd.read_csv('/content/2020-21_seasonAvgSplitPositions.csv')
df = df[['Date', 'Name', 'Team', 'Position', 'Salary', 'FPTS', param]]
# df = df[df.FPTS >= 0] # drop all players who scored less than 0 points
df.dropna(subset=[param], inplace=True)
df.shape
# Out:
# (75151, 7)

# %%
# for ridge reg heuristic

param = 'Pred2'

df = pd.read_csv('/content/2020-21_ridgeRegPredictions.csv')
df = df[['Date', 'Name', 'Team', 'Position', 'Salary', 'FPTS', param]]
# df = df[df.FPTS >= 0] # drop all players who scored less than 0 points
df.dropna(subset=[param], inplace=True)
df.shape
# Out:
# (75151, 7)

# %%
# for season average and ridge regression

param = 'RidgeRegPred'
df = pd.read_csv('/content/2020-21_SPLIT_seasonAvgAndRidgeReg.csv')
df = df[['Date', 'Name', 'Position', 'Salary', 'FPTS', 'SeasonAvgPred', 'RidgeRegPred']]
# df.sort_values(['Date','Salary', 'RidgeRegPred'], ascending=[True, True, False], inplace=True)
df.reset_index(inplace=True, drop=True)
df.shape
# Out:
# (75151, 7)

# %%
# all the dates that the brute force was able to run on
dates = df['Date'].unique()
len(dates)
# Out:
# 356

# %% [markdown]
# # Helper Functions

# %%
# returns a list of dataframes for each position
def buildPositionDFs(df1, order, sort=['Salary', 'FPTS'], incr=[True, False]):
  # incr determines if the players are each position are sorted by increasing salary
  l1 = []
  for i in order:
    # print(i)
    posDF = df1[df1['Position'] == i]
    posDF.sort_values(sort, ascending=incr, inplace=True)
    posDF.reset_index(inplace=True, drop=True)
    l1.append(posDF)
  return l1

# %%
# checkDuplicates takes in a dict of players, checks for duplicates
def checkDuplicates(players):
  setOfPlayers = set()
  for player in players.values():
      if player in setOfPlayers:
          return True
      else:
          setOfPlayers.add(player)         
  return False

# %%
# checkSalary takes in a dict of players, checks if salary > 50000
# if yes return true, else return false
def checkSalary(players):
  total_salary = getSalary(players)
  if total_salary > 50000:
    return True
  return False

# getSalary takes in a dict of players, returns the combined salary of all players
def getSalary(players):
  total_salary = 0
  for player in players.values():
    player_sal = currentPlayers[currentPlayers['Name'] == player].iloc[0].Salary
    total_salary += player_sal
  return total_salary

# %%
getSalary(lineup1[0])
# Out:
# 40000

# %%
def getSingleScore(player, df2, param):
  return df2[df2['Name'] == player].iloc[0][param]

# getScore takes in a dict of players, returns the fantasy points scored by players
def getScore(players, df_list, param):
  total_score = 0
  for pos in players:
    i = pos_idxs[pos]
    player_score = getSingleScore(players[pos], df_list[i], param)
    # print(player, player_score)
    total_score += player_score
  return total_score

# %%
def getPlayer(df1, date, player):
  return df1[(df1['Date'] == date) & (df1['Name'] == player)]

# %% [markdown]
# # test

# %% [markdown]
# naive avg: 176
#
# bruteforce avg: 286.54
#
# previous greedy selection avg: 262.54
#
# current greedy selection avg: 206.35
#
# genetic alg lineup selection avg: 360.22

# %%
# variables for the genetic algorithm
mu = 25
lamb = 25
generations = 50
mutation_rate = 0.25 # probabilty that a new element will undergo mutation
mutation_attempts = 10

crossover_rate = 0.5 # probabilty that a new element will undergo crossover
crossover_attempts = 10

# %%
def initialize_population(l1, mu, lamb, param):
  population = []
  while len(population) < mu+lamb:
    
    lineup = {}
    for i in range(len(l1)):
      player = l1[i].sample()

      lineup[positions[i]] = player['Name'].iloc[0]
      # print(player)
    
    if not checkDuplicates(lineup) and not checkSalary(lineup):
    # if not checkDuplicates(lineup):
      predScore = getScore(lineup, l1, param)
      FPTS = getScore(lineup, l1, 'FPTS')
      salary = getSalary(lineup)
      population.append([lineup, salary, predScore, FPTS])
    
  return population

# %%
def print_population(population):
  for i in range(len(population)):
    print(population[i][0])
    print(f'Salary: {population[i][1]},\tPredicted: {population[i][2]},\tFPTS: {population[i][3]}')

# %%
def mutate(lineup,mutation_rate,l1, param):
  old_lineup = lineup.copy()
  done = False
  num_tries = 0

  while not done and num_tries < mutation_attempts:
    # for each position in your lineup, replace current player with random player with probability mutation_rate
    # if doesn't violate any constraints we're done, otherwise reset the chromosome to its starting condition and try again
    players = old_lineup[0].copy()
    count = 0 # to make sure a mutation gets made
    
    # print(f'BEFORE: {players}')
    for pos in players:
      if random.random() < mutation_rate:
        count += 1
        # print(pos)
        idx = pos_idxs[pos]
        # print(idx)

        # num_tries += 1
        player = l1[idx].sample()
        player_name = player['Name'].iloc[0]

        # print(f'Swapping {pos}: {players[pos]} for {player_name}')

        players[pos] = player_name
    # print(f'AFTER: {players}')

    if not checkDuplicates(players) and not checkSalary(players) and count > 0:
      # print(f'Valid Lineup')
      lineup[0] = players
      lineup[1] = getSalary(players)
      lineup[2] = getScore(players, l1, param)
      lineup[3] = getScore(players, l1, 'FPTS')
      done = True
    num_tries += 1
  return lineup

# %%
# def crossover(lineup1,lineup2, crossover_rate):
def crossover(lineup1, lineup2, l1, param):
  done = False
  numTries = 0

  child = {}

  while not done and numTries<crossover_attempts:
  #for each position, pick the current player from either parent at random
  #if doesn't violate any constraints we're done, try again
    for pos in lineup1[0]:
      if random.random() < 0.5:
        child[pos] = lineup1[0][pos]
      else:
        child[pos] = lineup2[0][pos]
    
    salary = np.inf
    predScore = 0
    FPTS = 0
    if not checkDuplicates(child) and not checkSalary(child):
      # print('Valid lineup')
      salary = getSalary(child)
      predScore = getScore(child, l1, param)
      FPTS = getScore(child, l1, 'FPTS')
      done = True
      # print(child, salary, score)
    numTries += 1
  if salary == np.inf or predScore == 0 or FPTS == 0:
    print(child)
  return [child, salary, predScore, FPTS]

# %%
p1 = population[6]
p1
# Out:
# [{'PG': 'Shai Gilgeous-Alexander',
#   'SG': 'Evan Fournier',
#   'SF': 'Terrence Ross',
#   'PF': 'Joe Ingles',
#   'C': 'Richaun Holmes',
#   'G': 'Dillon Brooks',
#   'F': 'Lauri Markkanen',
#   'UTIL': 'Seth Curry'},
#  40600,
#  198.75,
#  198.75]

# %%
p2 = population[10]
p2
# Out:
# [{'PG': 'Ben Simmons',
#   'SG': 'Frank Ntilikina',
#   'SF': 'Doug McDermott',
#   'PF': 'Rui Hachimura',
#   'C': 'Joel Embiid',
#   'G': 'Allonzo Trier',
#   'F': 'Isaac Bonga',
#   'UTIL': 'Luke Kennard'},
#  39900,
#  186.75,
#  186.75]

# %%
c = crossover(p1, p2, l1, param)
c
# Out:
# [{'PG': 'Shai Gilgeous-Alexander',
#   'SG': 'Evan Fournier',
#   'SF': 'Doug McDermott',
#   'PF': 'Rui Hachimura',
#   'C': 'Richaun Holmes',
#   'G': 'Allonzo Trier',
#   'F': 'Lauri Markkanen',
#   'UTIL': 'Luke Kennard'},
#  37700,
#  210.5,
#  210.5]

# %%
mu, lamb, generations
# Out:
# (25, 25, 50)

# %%
positions = ['PG', 'SG', 'SF', 'PF', 'C', 'G', 'F', 'UTIL']
pos_idxs = {'PG':0, 'SG':1, 'SF':2, 'PF':3, 'C':4, 'G':5, 'F':6, 'UTIL':7 }
data = []

# %%
# for x in range(len(dates)):
for x in range(1,2):
  date = dates[x]
  print(x, date)

  # continue

  currentPlayers = df[df['Date']==date]

  l1 = buildPositionDFs(currentPlayers, positions)

  # initialize a population of size mu+lamb, consists of randomly generated valid lineups
  population = initialize_population(l1, mu, lamb, param)
  # print_population(population)

  break

  for generation in range(generations):
    if (generation%10 == 0):
      print(f'Generation {generation}')
      # print_population(population)
    # sort the population in descending order by param
    population = sorted(population, key=lambda x: x[2], reverse=True)

    # print_population(population)

    elites = population[0:mu] #the best mu are unchanged
    # print(len(elites))
    # print_population(elites)

    new_lineups = []
    for i in range(lamb):
      # create a copy of a random elite
      new_lineup = random.choice(elites).copy()
      # print(new_lineup)

      # alternatively, use each elite once
      # new_lineup = elites[i].copy()

      new_lineup = mutate(new_lineup, mutation_rate, l1, param)

      if random.random() < crossover_rate:
        # print('CROSSOVER')
        parent2 = random.choice(elites)
        new_lineup = crossover(new_lineup, parent2, l1, param)
      new_lineups.append(new_lineup)

    population = elites+new_lineups

  # print('Elites:')
  # print_population(elites)
  # print('Mutations:')
  # print_population(new_lineups)
  # print('Population:')
  # print_population(population)

  # resorting the population again
  # even though typically the best solutions are already at the front of the list
  population = sorted(population, key=lambda x: x[2], reverse=True)
  soln = population[0][0]

  soln['Date'] = date
  soln['Salary'] = population[0][1]
  soln['Prediction'] = population[0][2]
  soln['FPTS'] = population[0][3]
  print(soln)
  data.append(soln)
# Out:
# 1 20191023
# {'PG': 'Isaac Bonga', 'SG': 'Jordan McRae', 'SF': 'Matisse Thybulle', 'PF': 'Mason Plumlee', 'C': 'Caleb Swanigan', 'G': 'Ben Simmons', 'F': 'Wenyen Gabriel', 'UTIL': 'Treveon Graham'}
# Salary: 30900,	Predicted: 151.5,	FPTS: 151.5
# {'PG': 'Allonzo Trier', 'SG': 'Nicolas Batum', 'SF': 'Harrison Barnes', 'PF': 'Cedi Osman', 'C': 'Markieff Morris', 'G': 'Bryn Forbes', 'F': 'Justin Jackson', 'UTIL': 'Bogdan Bogdanovic'}
# Salary: 34000,	Predicted: 124.0,	FPTS: 124.0
# {'PG': 'Aaron Holiday', 'SG': 'Yogi Ferrell', 'SF': 'Mario Hezonja', 'PF': 'Richaun Holmes', 'C': 'Cody Zeller', 'G': 'Shabazz Napier', 'F': 'Davis Bertans', 'UTIL': 'Bryn Forbes'}
# Salary: 28700,	Predicted: 118.75,	FPTS: 118.75
# {'PG': 'Patty Mills', 'SG': 'Coby White', 'SF': 'Matisse Thybulle', 'PF': 'Kelly Olynyk', 'C': 'Ed Davis', 'G': 'Torrey Craig', 'F': 'Dillon Brooks', 'UTIL': 'Bryn Forbes'}
# Salary: 29600,	Predicted: 170.5,	FPTS: 170.5
# {'PG': 'Darius Garland', 'SG': 'Derrick White', 'SF': 'Torrey Craig', 'PF': 'Doug McDermott', 'C': 'Taj Gibson', 'G': 'Marco Belinelli', 'F': 'Isaac Bonga', 'UTIL': 'Wenyen Gabriel'}
# Salary: 29500,	Predicted: 102.25,	FPTS: 102.25
# {'PG': 'Monte Morris', 'SG': 'Kendrick Nunn', 'SF': 'KZ Okpala', 'PF': 'Julius Randle', 'C': 'PJ Washington', 'G': 'Tyus Jones', 'F': 'Tim Hardaway Jr', 'UTIL': 'Deandre Ayton'}
# Salary: 39000,	Predicted: 221.0,	FPTS: 221.0
# {'PG': 'Shai Gilgeous-Alexander', 'SG': 'Gary Harris', 'SF': 'Mike Scott', 'PF': 'Daniel Theis', 'C': 'Kelly Olynyk', 'G': 'DJ Augustin', 'F': 'Furkan Korkmaz', 'UTIL': 'Derrick Rose'}
# Salary: 34400,	Predicted: 151.75,	FPTS: 151.75
# {'PG': 'Mike Conley', 'SG': 'Wayne Ellington', 'SF': 'Royce ONeale', 'PF': 'Ed Davis', 'C': 'Kelly Olynyk', 'G': 'Monte Morris', 'F': 'Ben Simmons', 'UTIL': 'Hassan Whiteside'}
# Salary: 41100,	Predicted: 179.0,	FPTS: 179.0
# {'PG': 'Patty Mills', 'SG': 'Rodney Hood', 'SF': 'Tony Snell', 'PF': 'Maxi Kleber', 'C': 'Luke Kornet', 'G': 'Elfrid Payton', 'F': 'Kent Bazemore', 'UTIL': 'Derrick Rose'}
# Salary: 31800,	Predicted: 159.25,	FPTS: 159.25
# {'PG': 'Terry Rozier', 'SG': 'Josh Richardson', 'SF': 'Ben Simmons', 'PF': 'Trey Lyles', 'C': 'Rudy Gobert', 'G': 'Brad Wanamaker', 'F': 'Royce ONeale', 'UTIL': 'Meyers Leonard'}
# Salary: 42200,	Predicted: 173.75,	FPTS: 173.75
# {'PG': 'Malik Beasley', 'SG': 'Derrick Rose', 'SF': 'Matisse Thybulle', 'PF': 'Jerami Grant', 'C': 'Markieff Morris', 'G': 'Cory Joseph', 'F': 'Bam Adebayo', 'UTIL': 'Courtney Lee'}
# Salary: 33000,	Predicted: 145.75,	FPTS: 145.75
# {'PG': 'Bryn Forbes', 'SG': 'Coby White', 'SF': 'Kevin Knox', 'PF': 'Bobby Portis', 'C': 'Rudy Gobert', 'G': 'Ricky Rubio', 'F': 'Jarrett Culver', 'UTIL': 'Richaun Holmes'}
# Salary: 39500,	Predicted: 191.75,	FPTS: 191.75
# {'PG': 'Yogi Ferrell', 'SG': 'Patty Mills', 'SF': 'Wayne Ellington', 'PF': 'Darius Bazley', 'C': 'LaMarcus Aldridge', 'G': 'Courtney Lee', 'F': 'Treveon Graham', 'UTIL': 'Malcolm Brogdon'}
# Salary: 33000,	Predicted: 146.25,	FPTS: 146.25
# {'PG': 'Emmanuel Mudiay', 'SG': 'Jeremy Lamb', 'SF': 'Torrey Craig', 'PF': 'Taj Gibson', 'C': 'Kristaps Porzingis', 'G': 'Kendrick Nunn', 'F': 'Matisse Thybulle', 'UTIL': 'Thomas Bryant'}
# Salary: 38400,	Predicted: 191.0,	FPTS: 191.0
# {'PG': 'Carsen Edwards', 'SG': 'Patty Mills', 'SF': 'Danilo Gallinari', 'PF': 'KZ Okpala', 'C': 'Zach Collins', 'G': 'Tim Frazier', 'F': 'Robert Covington', 'UTIL': 'Andrew Wiggins'}
# Salary: 36400,	Predicted: 132.75,	FPTS: 132.75
# {'PG': 'Emmanuel Mudiay', 'SG': 'Shake Milton', 'SF': 'Wayne Ellington', 'PF': 'Christian Wood', 'C': 'Karl-Anthony Towns', 'G': 'Jordan McRae', 'F': 'Buddy Hield', 'UTIL': 'Jordan Clarkson'}
# Salary: 39900,	Predicted: 178.25,	FPTS: 178.25
# {'PG': 'DeAnthony Melton', 'SG': 'Kent Bazemore', 'SF': 'Marco Belinelli', 'PF': 'Domantas Sabonis', 'C': 'Daniel Theis', 'G': 'Gary Harris', 'F': 'Wenyen Gabriel', 'UTIL': 'Damian Lillard'}
# Salary: 37400,	Predicted: 146.25,	FPTS: 146.25
# {'PG': 'Isaac Bonga', 'SG': 'Anfernee Simons', 'SF': 'Marvin Williams', 'PF': 'Jayson Tatum', 'C': 'Moritz Wagner', 'G': 'Justin Robinson', 'F': 'Daniel Theis', 'UTIL': 'Marcus Morris'}
# Salary: 32400,	Predicted: 154.0,	FPTS: 154.0
# {'PG': 'Kendrick Nunn', 'SG': 'Allonzo Trier', 'SF': 'Wenyen Gabriel', 'PF': 'Domantas Sabonis', 'C': 'Nikola Vucevic', 'G': 'Daryl Macon', 'F': 'Kent Bazemore', 'UTIL': 'Semi Ojeleye'}
# Salary: 35300,	Predicted: 139.5,	FPTS: 139.5
# {'PG': 'Shai Gilgeous-Alexander', 'SG': 'Evan Fournier', 'SF': 'Terrence Ross', 'PF': 'Joe Ingles', 'C': 'Richaun Holmes', 'G': 'Dillon Brooks', 'F': 'Lauri Markkanen', 'UTIL': 'Seth Curry'}
# Salary: 40600,	Predicted: 198.75,	FPTS: 198.75
# {'PG': 'Anfernee Simons', 'SG': 'Hamidou Diallo', 'SF': 'Thaddeus Young', 'PF': 'Brandon Clarke', 'C': 'Markieff Morris', 'G': 'Emmanuel Mudiay', 'F': 'Gordon Hayward', 'UTIL': 'Isaac Bonga'}
# Salary: 32600,	Predicted: 167.25,	FPTS: 167.25
# {'PG': 'Justise Winslow', 'SG': 'Derrick White', 'SF': 'Grant Williams', 'PF': 'Noah Vonleh', 'C': 'Cody Zeller', 'G': 'Josh Okogie', 'F': 'Dillon Brooks', 'UTIL': 'Jakob Poeltl'}
# Salary: 33100,	Predicted: 164.5,	FPTS: 164.5
# {'PG': 'Coby White', 'SG': 'Rodney Hood', 'SF': 'Thaddeus Young', 'PF': 'Jeff Green', 'C': 'Andre Drummond', 'G': 'Jeremy Lamb', 'F': 'Jonathan Isaac', 'UTIL': 'KZ Okpala'}
# Salary: 40000,	Predicted: 210.25,	FPTS: 210.25
# {'PG': 'TJ McConnell', 'SG': 'Reggie Jackson', 'SF': 'Harrison Barnes', 'PF': 'Christian Wood', 'C': 'Bobby Portis', 'G': 'Jaylen Brown', 'F': 'Mikal Bridges', 'UTIL': 'Mike Scott'}
# Salary: 35500,	Predicted: 126.25,	FPTS: 126.25
# {'PG': 'Ben Simmons', 'SG': 'Frank Ntilikina', 'SF': 'Doug McDermott', 'PF': 'Rui Hachimura', 'C': 'Joel Embiid', 'G': 'Allonzo Trier', 'F': 'Isaac Bonga', 'UTIL': 'Luke Kennard'}
# Salary: 39900,	Predicted: 186.75,	FPTS: 186.75
# {'PG': 'Reggie Jackson', 'SG': 'Yogi Ferrell', 'SF': 'Terrance Ferguson', 'PF': 'Kyle Anderson', 'C': 'Richaun Holmes', 'G': 'Jamal Murray', 'F': 'Thaddeus Young', 'UTIL': 'Jake Layman'}
# Salary: 33000,	Predicted: 123.75,	FPTS: 123.75
# {'PG': 'Terry Rozier', 'SG': 'DeAnthony Melton', 'SF': 'Furkan Korkmaz', 'PF': 'Georges Niang', 'C': 'Brandon Clarke', 'G': 'Kent Bazemore', 'F': 'Cheick Diallo', 'UTIL': 'Shake Milton'}
# Salary: 30500,	Predicted: 75.5,	FPTS: 75.5
# {'PG': 'Matthew Dellavedova', 'SG': 'Jevon Carter', 'SF': 'Kent Bazemore', 'PF': 'TJ Leaf', 'C': 'Frank Kaminsky', 'G': 'Edmond Sumner', 'F': 'Bam Adebayo', 'UTIL': 'Malcolm Brogdon'}
# Salary: 33700,	Predicted: 162.0,	FPTS: 162.0
# {'PG': 'Allonzo Trier', 'SG': 'Terrance Ferguson', 'SF': 'Treveon Graham', 'PF': 'Jayson Tatum', 'C': 'Cody Zeller', 'G': 'Evan Fournier', 'F': 'Kelly Olynyk', 'UTIL': 'Karl-Anthony Towns'}
# Salary: 40500,	Predicted: 229.25,	FPTS: 229.25
# {'PG': 'Emmanuel Mudiay', 'SG': 'Evan Fournier', 'SF': 'Trevor Ariza', 'PF': 'Moritz Wagner', 'C': 'Karl-Anthony Towns', 'G': 'Will Barton', 'F': 'Miles Bridges', 'UTIL': 'Seth Curry'}
# Salary: 40400,	Predicted: 223.75,	FPTS: 223.75
# {'PG': 'Elfrid Payton', 'SG': 'Yogi Ferrell', 'SF': 'Matisse Thybulle', 'PF': 'Joe Ingles', 'C': 'Markieff Morris', 'G': 'DeMar DeRozan', 'F': 'Justin Jackson', 'UTIL': 'Nikola Jokic'}
# Salary: 40400,	Predicted: 167.75,	FPTS: 167.75
# {'PG': 'Josh Richardson', 'SG': 'Devonte Graham', 'SF': 'Tim Hardaway Jr', 'PF': 'Jerami Grant', 'C': 'Cheick Diallo', 'G': 'Jamal Murray', 'F': 'Aaron Gordon', 'UTIL': 'Furkan Korkmaz'}
# Salary: 37000,	Predicted: 159.5,	FPTS: 159.5
# {'PG': 'Chris Chiozza', 'SG': 'Frank Ntilikina', 'SF': 'Will Barton', 'PF': 'Markieff Morris', 'C': 'Cody Zeller', 'G': 'Jordan Clarkson', 'F': 'Darius Bazley', 'UTIL': 'Cory Joseph'}
# Salary: 30000,	Predicted: 142.0,	FPTS: 142.0
# {'PG': 'Ricky Rubio', 'SG': 'Courtney Lee', 'SF': 'Admiral Schofield', 'PF': 'Mario Hezonja', 'C': 'Markieff Morris', 'G': 'Jevon Carter', 'F': 'Luke Kennard', 'UTIL': 'Evan Fournier'}
# Salary: 30800,	Predicted: 162.0,	FPTS: 162.0
# {'PG': 'Jalen Brunson', 'SG': 'Seth Curry', 'SF': 'Cedi Osman', 'PF': 'Doug McDermott', 'C': 'Noah Vonleh', 'G': 'TJ McConnell', 'F': 'Jeremy Lamb', 'UTIL': 'DeMar DeRozan'}
# Salary: 35300,	Predicted: 139.25,	FPTS: 139.25
# {'PG': 'Elfrid Payton', 'SG': 'Coby White', 'SF': 'Rodney Hood', 'PF': 'Noah Vonleh', 'C': 'Myles Turner', 'G': 'Dennis Smith Jr', 'F': 'Daniel Theis', 'UTIL': 'Matthew Dellavedova'}
# Salary: 34600,	Predicted: 168.75,	FPTS: 168.75
# {'PG': 'Jamal Murray', 'SG': 'Malik Beasley', 'SF': 'Trevor Ariza', 'PF': 'TJ Leaf', 'C': 'Hassan Whiteside', 'G': 'Marco Belinelli', 'F': 'Frank Kaminsky', 'UTIL': 'Derrick Rose'}
# Salary: 35000,	Predicted: 152.0,	FPTS: 152.0
# {'PG': 'Mike Conley', 'SG': 'Bogdan Bogdanovic', 'SF': 'Davis Bertans', 'PF': 'Julius Randle', 'C': 'Noah Vonleh', 'G': 'Bruce Brown', 'F': 'Jerami Grant', 'UTIL': 'Ben Simmons'}
# Salary: 44000,	Predicted: 177.75,	FPTS: 177.75
# {'PG': 'CJ McCollum', 'SG': 'Kris Dunn', 'SF': 'Dillon Brooks', 'PF': 'Georges Niang', 'C': 'Jerami Grant', 'G': 'Tim Hardaway Jr', 'F': 'Justin Holiday', 'UTIL': 'Damian Lillard'}
# Salary: 38900,	Predicted: 141.0,	FPTS: 141.0
# {'PG': 'Dennis Schroder', 'SG': 'Will Barton', 'SF': 'Jeremy Lamb', 'PF': 'Doug McDermott', 'C': 'Deandre Ayton', 'G': 'Jeff Teague', 'F': 'LaMarcus Aldridge', 'UTIL': 'Dwayne Bacon'}
# Salary: 43600,	Predicted: 221.5,	FPTS: 221.5
# {'PG': 'RJ Barrett', 'SG': 'Torrey Craig', 'SF': 'DeMar DeRozan', 'PF': 'Kevin Love', 'C': 'Ed Davis', 'G': 'Brad Wanamaker', 'F': 'Marko Guduric', 'UTIL': 'Darius Bazley'}
# Salary: 36700,	Predicted: 155.5,	FPTS: 155.5
# {'PG': 'Daryl Macon', 'SG': 'Bradley Beal', 'SF': 'Tobias Harris', 'PF': 'Nemanja Bjelica', 'C': 'Nikola Vucevic', 'G': 'DJ Augustin', 'F': 'Lauri Markkanen', 'UTIL': 'Tim Frazier'}
# Salary: 46900,	Predicted: 229.0,	FPTS: 229.0
# {'PG': 'Grayson Allen', 'SG': 'Collin Sexton', 'SF': 'Royce ONeale', 'PF': 'Mike Muscala', 'C': 'Nerlens Noel', 'G': 'Patty Mills', 'F': 'Jonathan Isaac', 'UTIL': 'Bruno Caboclo'}
# Salary: 30800,	Predicted: 120.75,	FPTS: 120.75
# {'PG': 'Darius Garland', 'SG': 'Kent Bazemore', 'SF': 'TJ Leaf', 'PF': 'Al Horford', 'C': 'Luke Kornet', 'G': 'Malik Monk', 'F': 'Wenyen Gabriel', 'UTIL': 'DeAnthony Melton'}
# Salary: 31100,	Predicted: 85.75,	FPTS: 85.75
# {'PG': 'Kris Dunn', 'SG': 'Malcolm Brogdon', 'SF': 'Duncan Robinson', 'PF': 'Robert Williams', 'C': 'Jakob Poeltl', 'G': 'Kemba Walker', 'F': 'Meyers Leonard', 'UTIL': 'Markelle Fultz'}
# Salary: 36100,	Predicted: 150.5,	FPTS: 150.5
# {'PG': 'Ben Simmons', 'SG': 'Anfernee Simons', 'SF': 'Jae Crowder', 'PF': 'Frank Kaminsky', 'C': 'Richaun Holmes', 'G': 'Dwayne Bacon', 'F': 'Daniel Theis', 'UTIL': 'Jaylen Brown'}
# Salary: 37800,	Predicted: 166.25,	FPTS: 166.25
# {'PG': 'Matthew Dellavedova', 'SG': 'Collin Sexton', 'SF': 'Jeremy Lamb', 'PF': 'Bojan Bogdanovic', 'C': 'Jakob Poeltl', 'G': 'Torrey Craig', 'F': 'Al Horford', 'UTIL': 'Goran Dragic'}
# Salary: 37400,	Predicted: 173.75,	FPTS: 173.75
# {'PG': 'Kemba Walker', 'SG': 'Jarrett Culver', 'SF': 'Semi Ojeleye', 'PF': 'Moritz Wagner', 'C': 'Caleb Swanigan', 'G': 'Markelle Fultz', 'F': 'DeMar DeRozan', 'UTIL': 'Dewayne Dedmon'}
# Salary: 37800,	Predicted: 105.25,	FPTS: 105.25
# {'PG': 'Cory Joseph', 'SG': 'Gary Harris', 'SF': 'Tobias Harris', 'PF': 'Dario Saric', 'C': 'Andre Drummond', 'G': 'Seth Curry', 'F': 'Nicolas Batum', 'UTIL': 'Justin Robinson'}
# Salary: 40000,	Predicted: 193.25,	FPTS: 193.25
# {'PG': 'Ja Morant', 'SG': 'CJ McCollum', 'SF': 'Al-Farouq Aminu', 'PF': 'Darius Bazley', 'C': 'Frank Kaminsky', 'G': 'Will Barton', 'F': 'Miles Bridges', 'UTIL': 'Duncan Robinson'}
# Salary: 37200,	Predicted: 148.5,	FPTS: 148.5

# %%
data = []

# for visualizing genetic algorithms
for i in range(len(population)):
  ind = population[i][0].copy()
  ind['Salary'] = population[i][1]
  ind['FPTS'] = population[i][3]
  # print(ind)
  data.append(ind)

pop = pd.DataFrame(data)
pop.to_csv(f'initialization.csv', line_terminator='\n', index=False)

# %%
population = sorted(population, key=lambda x: x[2], reverse=True)
population
# Out:
# [[{'PG': 'Allonzo Trier',
#    'SG': 'Terrance Ferguson',
#    'SF': 'Treveon Graham',
#    'PF': 'Jayson Tatum',
#    'C': 'Cody Zeller',
#    'G': 'Evan Fournier',
#    'F': 'Kelly Olynyk',
#    'UTIL': 'Karl-Anthony Towns'},
#   40500,
#   229.25,
#   229.25],
#  [{'PG': 'Daryl Macon',
#    'SG': 'Bradley Beal',
#    'SF': 'Tobias Harris',
#    'PF': 'Nemanja Bjelica',
#    'C': 'Nikola Vucevic',
#    'G': 'DJ Augustin',
#    'F': 'Lauri Markkanen',
#    'UTIL': 'Tim Frazier'},
#   46900,
#   229.0,
#   229.0],
#  [{'PG': 'Emmanuel Mudiay',
#    'SG': 'Evan Fournier',
#    'SF': 'Trevor Ariza',
#    'PF': 'Moritz Wagner',
#    'C': 'Karl-Anthony Towns',
#    'G': 'Will Barton',
#    'F': 'Miles Bridges',
#    'UTIL': 'Seth Curry'},
#   40400,
#   223.75,
#   223.75],
#  [{'PG': 'Dennis Schroder',
#    'SG': 'Will Barton',
#    'SF': 'Jeremy Lamb',
#    'PF': 'Doug McDermott',
#    'C': 'Deandre Ayton',
#    'G': 'Jeff Teague',
#    'F': 'LaMarcus Aldridge',
#    'UTIL': 'Dwayne Bacon'},
#   43600,
#   221.5,
#   221.5],
#  [{'PG': 'Monte Morris',
#    'SG': 'Kendrick Nunn',
#    'SF': 'KZ Okpala',
#    'PF': 'Julius Randle',
#    'C': 'PJ Washington',
#    'G': 'Tyus Jones',
#    'F': 'Tim Hardaway Jr',
#    'UTIL': 'Deandre Ayton'},
#   39000,
#   221.0,
#   221.0],
#  [{'PG': 'Coby White',
#    'SG': 'Rodney Hood',
#    'SF': 'Thaddeus Young',
#    'PF': 'Jeff Green',
#    'C': 'Andre Drummond',
#    'G': 'Jeremy Lamb',
#    'F': 'Jonathan Isaac',
#    'UTIL': 'KZ Okpala'},
#   40000,
#   210.25,
#   210.25],
#  [{'PG': 'Shai Gilgeous-Alexander',
#    'SG': 'Evan Fournier',
#    'SF': 'Terrence Ross',
#    'PF': 'Joe Ingles',
#    'C': 'Richaun Holmes',
#    'G': 'Dillon Brooks',
#    'F': 'Lauri Markkanen',
#    'UTIL': 'Seth Curry'},
#   40600,
#   198.75,
#   198.75],
#  [{'PG': 'Cory Joseph',
#    'SG': 'Gary Harris',
#    'SF': 'Tobias Harris',
#    'PF': 'Dario Saric',
#    'C': 'Andre Drummond',
#    'G': 'Seth Curry',
#    'F': 'Nicolas Batum',
#    'UTIL': 'Justin Robinson'},
#   40000,
#   193.25,
#   193.25],
#  [{'PG': 'Bryn Forbes',
#    'SG': 'Coby White',
#    'SF': 'Kevin Knox',
#    'PF': 'Bobby Portis',
#    'C': 'Rudy Gobert',
#    'G': 'Ricky Rubio',
#    'F': 'Jarrett Culver',
#    'UTIL': 'Richaun Holmes'},
#   39500,
#   191.75,
#   191.75],
#  [{'PG': 'Emmanuel Mudiay',
#    'SG': 'Jeremy Lamb',
#    'SF': 'Torrey Craig',
#    'PF': 'Taj Gibson',
#    'C': 'Kristaps Porzingis',
#    'G': 'Kendrick Nunn',
#    'F': 'Matisse Thybulle',
#    'UTIL': 'Thomas Bryant'},
#   38400,
#   191.0,
#   191.0],
#  [{'PG': 'Ben Simmons',
#    'SG': 'Frank Ntilikina',
#    'SF': 'Doug McDermott',
#    'PF': 'Rui Hachimura',
#    'C': 'Joel Embiid',
#    'G': 'Allonzo Trier',
#    'F': 'Isaac Bonga',
#    'UTIL': 'Luke Kennard'},
#   39900,
#   186.75,
#   186.75],
#  [{'PG': 'Mike Conley',
#    'SG': 'Wayne Ellington',
#    'SF': 'Royce ONeale',
#    'PF': 'Ed Davis',
#    'C': 'Kelly Olynyk',
#    'G': 'Monte Morris',
#    'F': 'Ben Simmons',
#    'UTIL': 'Hassan Whiteside'},
#   41100,
#   179.0,
#   179.0],
#  [{'PG': 'Emmanuel Mudiay',
#    'SG': 'Shake Milton',
#    'SF': 'Wayne Ellington',
#    'PF': 'Christian Wood',
#    'C': 'Karl-Anthony Towns',
#    'G': 'Jordan McRae',
#    'F': 'Buddy Hield',
#    'UTIL': 'Jordan Clarkson'},
#   39900,
#   178.25,
#   178.25],
#  [{'PG': 'Mike Conley',
#    'SG': 'Bogdan Bogdanovic',
#    'SF': 'Davis Bertans',
#    'PF': 'Julius Randle',
#    'C': 'Noah Vonleh',
#    'G': 'Bruce Brown',
#    'F': 'Jerami Grant',
#    'UTIL': 'Ben Simmons'},
#   44000,
#   177.75,
#   177.75],
#  [{'PG': 'Terry Rozier',
#    'SG': 'Josh Richardson',
#    'SF': 'Ben Simmons',
#    'PF': 'Trey Lyles',
#    'C': 'Rudy Gobert',
#    'G': 'Brad Wanamaker',
#    'F': 'Royce ONeale',
#    'UTIL': 'Meyers Leonard'},
#   42200,
#   173.75,
#   173.75],
#  [{'PG': 'Matthew Dellavedova',
#    'SG': 'Collin Sexton',
#    'SF': 'Jeremy Lamb',
#    'PF': 'Bojan Bogdanovic',
#    'C': 'Jakob Poeltl',
#    'G': 'Torrey Craig',
#    'F': 'Al Horford',
#    'UTIL': 'Goran Dragic'},
#   37400,
#   173.75,
#   173.75],
#  [{'PG': 'Patty Mills',
#    'SG': 'Coby White',
#    'SF': 'Matisse Thybulle',
#    'PF': 'Kelly Olynyk',
#    'C': 'Ed Davis',
#    'G': 'Torrey Craig',
#    'F': 'Dillon Brooks',
#    'UTIL': 'Bryn Forbes'},
#   29600,
#   170.5,
#   170.5],
#  [{'PG': 'Elfrid Payton',
#    'SG': 'Coby White',
#    'SF': 'Rodney Hood',
#    'PF': 'Noah Vonleh',
#    'C': 'Myles Turner',
#    'G': 'Dennis Smith Jr',
#    'F': 'Daniel Theis',
#    'UTIL': 'Matthew Dellavedova'},
#   34600,
#   168.75,
#   168.75],
#  [{'PG': 'Elfrid Payton',
#    'SG': 'Yogi Ferrell',
#    'SF': 'Matisse Thybulle',
#    'PF': 'Joe Ingles',
#    'C': 'Markieff Morris',
#    'G': 'DeMar DeRozan',
#    'F': 'Justin Jackson',
#    'UTIL': 'Nikola Jokic'},
#   40400,
#   167.75,
#   167.75],
#  [{'PG': 'Anfernee Simons',
#    'SG': 'Hamidou Diallo',
#    'SF': 'Thaddeus Young',
#    'PF': 'Brandon Clarke',
#    'C': 'Markieff Morris',
#    'G': 'Emmanuel Mudiay',
#    'F': 'Gordon Hayward',
#    'UTIL': 'Isaac Bonga'},
#   32600,
#   167.25,
#   167.25],
#  [{'PG': 'Ben Simmons',
#    'SG': 'Anfernee Simons',
#    'SF': 'Jae Crowder',
#    'PF': 'Frank Kaminsky',
#    'C': 'Richaun Holmes',
#    'G': 'Dwayne Bacon',
#    'F': 'Daniel Theis',
#    'UTIL': 'Jaylen Brown'},
#   37800,
#   166.25,
#   166.25],
#  [{'PG': 'Justise Winslow',
#    'SG': 'Derrick White',
#    'SF': 'Grant Williams',
#    'PF': 'Noah Vonleh',
#    'C': 'Cody Zeller',
#    'G': 'Josh Okogie',
#    'F': 'Dillon Brooks',
#    'UTIL': 'Jakob Poeltl'},
#   33100,
#   164.5,
#   164.5],
#  [{'PG': 'Matthew Dellavedova',
#    'SG': 'Jevon Carter',
#    'SF': 'Kent Bazemore',
#    'PF': 'TJ Leaf',
#    'C': 'Frank Kaminsky',
#    'G': 'Edmond Sumner',
#    'F': 'Bam Adebayo',
#    'UTIL': 'Malcolm Brogdon'},
#   33700,
#   162.0,
#   162.0],
#  [{'PG': 'Ricky Rubio',
#    'SG': 'Courtney Lee',
#    'SF': 'Admiral Schofield',
#    'PF': 'Mario Hezonja',
#    'C': 'Markieff Morris',
#    'G': 'Jevon Carter',
#    'F': 'Luke Kennard',
#    'UTIL': 'Evan Fournier'},
#   30800,
#   162.0,
#   162.0],
#  [{'PG': 'Josh Richardson',
#    'SG': 'Devonte Graham',
#    'SF': 'Tim Hardaway Jr',
#    'PF': 'Jerami Grant',
#    'C': 'Cheick Diallo',
#    'G': 'Jamal Murray',
#    'F': 'Aaron Gordon',
#    'UTIL': 'Furkan Korkmaz'},
#   37000,
#   159.5,
#   159.5],
#  [{'PG': 'Patty Mills',
#    'SG': 'Rodney Hood',
#    'SF': 'Tony Snell',
#    'PF': 'Maxi Kleber',
#    'C': 'Luke Kornet',
#    'G': 'Elfrid Payton',
#    'F': 'Kent Bazemore',
#    'UTIL': 'Derrick Rose'},
#   31800,
#   159.25,
#   159.25],
#  [{'PG': 'RJ Barrett',
#    'SG': 'Torrey Craig',
#    'SF': 'DeMar DeRozan',
#    'PF': 'Kevin Love',
#    'C': 'Ed Davis',
#    'G': 'Brad Wanamaker',
#    'F': 'Marko Guduric',
#    'UTIL': 'Darius Bazley'},
#   36700,
#   155.5,
#   155.5],
#  [{'PG': 'Isaac Bonga',
#    'SG': 'Anfernee Simons',
#    'SF': 'Marvin Williams',
#    'PF': 'Jayson Tatum',
#    'C': 'Moritz Wagner',
#    'G': 'Justin Robinson',
#    'F': 'Daniel Theis',
#    'UTIL': 'Marcus Morris'},
#   32400,
#   154.0,
#   154.0],
#  [{'PG': 'Jamal Murray',
#    'SG': 'Malik Beasley',
#    'SF': 'Trevor Ariza',
#    'PF': 'TJ Leaf',
#    'C': 'Hassan Whiteside',
#    'G': 'Marco Belinelli',
#    'F': 'Frank Kaminsky',
#    'UTIL': 'Derrick Rose'},
#   35000,
#   152.0,
#   152.0],
#  [{'PG': 'Shai Gilgeous-Alexander',
#    'SG': 'Gary Harris',
#    'SF': 'Mike Scott',
#    'PF': 'Daniel Theis',
#    'C': 'Kelly Olynyk',
#    'G': 'DJ Augustin',
#    'F': 'Furkan Korkmaz',
#    'UTIL': 'Derrick Rose'},
#   34400,
#   151.75,
#   151.75],
#  [{'PG': 'Isaac Bonga',
#    'SG': 'Jordan McRae',
#    'SF': 'Matisse Thybulle',
#    'PF': 'Mason Plumlee',
#    'C': 'Caleb Swanigan',
#    'G': 'Ben Simmons',
#    'F': 'Wenyen Gabriel',
#    'UTIL': 'Treveon Graham'},
#   30900,
#   151.5,
#   151.5],
#  [{'PG': 'Kris Dunn',
#    'SG': 'Malcolm Brogdon',
#    'SF': 'Duncan Robinson',
#    'PF': 'Robert Williams',
#    'C': 'Jakob Poeltl',
#    'G': 'Kemba Walker',
#    'F': 'Meyers Leonard',
#    'UTIL': 'Markelle Fultz'},
#   36100,
#   150.5,
#   150.5],
#  [{'PG': 'Ja Morant',
#    'SG': 'CJ McCollum',
#    'SF': 'Al-Farouq Aminu',
#    'PF': 'Darius Bazley',
#    'C': 'Frank Kaminsky',
#    'G': 'Will Barton',
#    'F': 'Miles Bridges',
#    'UTIL': 'Duncan Robinson'},
#   37200,
#   148.5,
#   148.5],
#  [{'PG': 'Yogi Ferrell',
#    'SG': 'Patty Mills',
#    'SF': 'Wayne Ellington',
#    'PF': 'Darius Bazley',
#    'C': 'LaMarcus Aldridge',
#    'G': 'Courtney Lee',
#    'F': 'Treveon Graham',
#    'UTIL': 'Malcolm Brogdon'},
#   33000,
#   146.25,
#   146.25],
#  [{'PG': 'DeAnthony Melton',
#    'SG': 'Kent Bazemore',
#    'SF': 'Marco Belinelli',
#    'PF': 'Domantas Sabonis',
#    'C': 'Daniel Theis',
#    'G': 'Gary Harris',
#    'F': 'Wenyen Gabriel',
#    'UTIL': 'Damian Lillard'},
#   37400,
#   146.25,
#   146.25],
#  [{'PG': 'Malik Beasley',
#    'SG': 'Derrick Rose',
#    'SF': 'Matisse Thybulle',
#    'PF': 'Jerami Grant',
#    'C': 'Markieff Morris',
#    'G': 'Cory Joseph',
#    'F': 'Bam Adebayo',
#    'UTIL': 'Courtney Lee'},
#   33000,
#   145.75,
#   145.75],
#  [{'PG': 'Chris Chiozza',
#    'SG': 'Frank Ntilikina',
#    'SF': 'Will Barton',
#    'PF': 'Markieff Morris',
#    'C': 'Cody Zeller',
#    'G': 'Jordan Clarkson',
#    'F': 'Darius Bazley',
#    'UTIL': 'Cory Joseph'},
#   30000,
#   142.0,
#   142.0],
#  [{'PG': 'CJ McCollum',
#    'SG': 'Kris Dunn',
#    'SF': 'Dillon Brooks',
#    'PF': 'Georges Niang',
#    'C': 'Jerami Grant',
#    'G': 'Tim Hardaway Jr',
#    'F': 'Justin Holiday',
#    'UTIL': 'Damian Lillard'},
#   38900,
#   141.0,
#   141.0],
#  [{'PG': 'Kendrick Nunn',
#    'SG': 'Allonzo Trier',
#    'SF': 'Wenyen Gabriel',
#    'PF': 'Domantas Sabonis',
#    'C': 'Nikola Vucevic',
#    'G': 'Daryl Macon',
#    'F': 'Kent Bazemore',
#    'UTIL': 'Semi Ojeleye'},
#   35300,
#   139.5,
#   139.5],
#  [{'PG': 'Jalen Brunson',
#    'SG': 'Seth Curry',
#    'SF': 'Cedi Osman',
#    'PF': 'Doug McDermott',
#    'C': 'Noah Vonleh',
#    'G': 'TJ McConnell',
#    'F': 'Jeremy Lamb',
#    'UTIL': 'DeMar DeRozan'},
#   35300,
#   139.25,
#   139.25],
#  [{'PG': 'Carsen Edwards',
#    'SG': 'Patty Mills',
#    'SF': 'Danilo Gallinari',
#    'PF': 'KZ Okpala',
#    'C': 'Zach Collins',
#    'G': 'Tim Frazier',
#    'F': 'Robert Covington',
#    'UTIL': 'Andrew Wiggins'},
#   36400,
#   132.75,
#   132.75],
#  [{'PG': 'TJ McConnell',
#    'SG': 'Reggie Jackson',
#    'SF': 'Harrison Barnes',
#    'PF': 'Christian Wood',
#    'C': 'Bobby Portis',
#    'G': 'Jaylen Brown',
#    'F': 'Mikal Bridges',
#    'UTIL': 'Mike Scott'},
#   35500,
#   126.25,
#   126.25],
#  [{'PG': 'Allonzo Trier',
#    'SG': 'Nicolas Batum',
#    'SF': 'Harrison Barnes',
#    'PF': 'Cedi Osman',
#    'C': 'Markieff Morris',
#    'G': 'Bryn Forbes',
#    'F': 'Justin Jackson',
#    'UTIL': 'Bogdan Bogdanovic'},
#   34000,
#   124.0,
#   124.0],
#  [{'PG': 'Reggie Jackson',
#    'SG': 'Yogi Ferrell',
#    'SF': 'Terrance Ferguson',
#    'PF': 'Kyle Anderson',
#    'C': 'Richaun Holmes',
#    'G': 'Jamal Murray',
#    'F': 'Thaddeus Young',
#    'UTIL': 'Jake Layman'},
#   33000,
#   123.75,
#   123.75],
#  [{'PG': 'Grayson Allen',
#    'SG': 'Collin Sexton',
#    'SF': 'Royce ONeale',
#    'PF': 'Mike Muscala',
#    'C': 'Nerlens Noel',
#    'G': 'Patty Mills',
#    'F': 'Jonathan Isaac',
#    'UTIL': 'Bruno Caboclo'},
#   30800,
#   120.75,
#   120.75],
#  [{'PG': 'Aaron Holiday',
#    'SG': 'Yogi Ferrell',
#    'SF': 'Mario Hezonja',
#    'PF': 'Richaun Holmes',
#    'C': 'Cody Zeller',
#    'G': 'Shabazz Napier',
#    'F': 'Davis Bertans',
#    'UTIL': 'Bryn Forbes'},
#   28700,
#   118.75,
#   118.75],
#  [{'PG': 'Kemba Walker',
#    'SG': 'Jarrett Culver',
#    'SF': 'Semi Ojeleye',
#    'PF': 'Moritz Wagner',
#    'C': 'Caleb Swanigan',
#    'G': 'Markelle Fultz',
#    'F': 'DeMar DeRozan',
#    'UTIL': 'Dewayne Dedmon'},
#   37800,
#   105.25,
#   105.25],
#  [{'PG': 'Darius Garland',
#    'SG': 'Derrick White',
#    'SF': 'Torrey Craig',
#    'PF': 'Doug McDermott',
#    'C': 'Taj Gibson',
#    'G': 'Marco Belinelli',
#    'F': 'Isaac Bonga',
#    'UTIL': 'Wenyen Gabriel'},
#   29500,
#   102.25,
#   102.25],
#  [{'PG': 'Darius Garland',
#    'SG': 'Kent Bazemore',
#    'SF': 'TJ Leaf',
#    'PF': 'Al Horford',
#    'C': 'Luke Kornet',
#    'G': 'Malik Monk',
#    'F': 'Wenyen Gabriel',
#    'UTIL': 'DeAnthony Melton'},
#   31100,
#   85.75,
#   85.75],
#  [{'PG': 'Terry Rozier',
#    'SG': 'DeAnthony Melton',
#    'SF': 'Furkan Korkmaz',
#    'PF': 'Georges Niang',
#    'C': 'Brandon Clarke',
#    'G': 'Kent Bazemore',
#    'F': 'Cheick Diallo',
#    'UTIL': 'Shake Milton'},
#   30500,
#   75.5,
#   75.5]]

# %%
data

# %%
soln_df = pd.DataFrame(data)
soln_df
# Out:
#                     PG                 SG               SF  \
# 0          Jeff Teague       Jaylen Brown  Khris Middleton
# 1         Terry Rozier         Joe Ingles    Terrence Ross
# 2       Darius Garland         Alec Burks    Terrence Ross
# 3          George Hill       James Harden     Josh Jackson
# 4         Monte Morris    Duncan Robinson   Brandon Ingram
# ..                 ...                ...              ...
# 167  Bogdan Bogdanovic        Bryn Forbes  Pat Connaughton
# 168         Chris Paul       Devin Booker    Nicolas Batum
# 169        Jeff Teague  Bogdan Bogdanovic  Khris Middleton
# 170      Cameron Payne       Devin Booker    Nicolas Batum
# 171  Bogdan Bogdanovic       Jrue Holiday  Khris Middleton
#
#                         PF                 C                G  \
# 0           Brandon Ingram  Montrezl Harrell     Goran Dragic
# 1            Julius Randle  Domantas Sabonis  Dejounte Murray
# 2            DeMar DeRozan    Nikola Vucevic  Dejounte Murray
# 3            Darius Bazley    Christian Wood        Ja Morant
# 4            Nicolas Batum    Andre Drummond    Luguentz Dort
# ..                     ...               ...              ...
# 167  Giannis Antetokounmpo       Brook Lopez       Trae Young
# 168          Marcus Morris     Deandre Ayton      Paul George
# 169           John Collins      Clint Capela      Cam Reddish
# 170          Marcus Morris  DeMarcus Cousins       Chris Paul
# 171           John Collins      Clint Capela      Cam Reddish
#
#                          F                 UTIL      Date  Salary  Prediction  \
# 0              Maxi Kleber          Bam Adebayo  20201225   49500  331.921177
# 1          Harrison Barnes       Keldon Johnson  20201226   49600  329.314797
# 2         Domantas Sabonis           Dante Exum  20201227   49800  317.937673
# 3            Dillon Brooks  Talen Horton-Tucker  20201228   49700  339.276206
# 4             Josh Jackson         Nikola Jokic  20201229   49700  305.518754
# ..                     ...                  ...       ...     ...         ...
# 167           Bobby Portis         Clint Capela  20210627   49800  244.565422
# 168            Dario Saric     DeMarcus Cousins  20210628   49700  234.972763
# 169  Giannis Antetokounmpo         Bobby Portis  20210629   50000  244.947555
# 170          Mikal Bridges          Paul George  20210630   49300  231.938788
# 171           Bobby Portis        Kevin Huerter  20210701   49800  236.586819
#
#        FPTS
# 0    252.75
# 1    271.00
# 2    243.25
# 3    253.50
# 4    274.00
# ..      ...
# 167  221.00
# 168  262.50
# 169  193.75
# 170  258.50
# 171  311.25
#
# [172 rows x 12 columns]

# %%
soln_df['Prediction'].mean()
# Out:
# 260.2727041774657

# %%
soln_df.to_csv(f'{param}geneticAlg.csv', line_terminator='\n', index=False)

# %% [markdown]
# # Double Checking Genetic Algorithm Oracle Results

# %%
soln_df = pd.read_csv('geneticAlgOracleResults.csv')

# %%
soln_df
# Out:
#                     PG                        SG                SF  \
# 0      Dennis Schroder  Kentavious Caldwell-Pope   Thabo Sefolosha
# 1          Ricky Rubio              Bradley Beal  Danilo Gallinari
# 2          Jeff Teague                  CJ Miles   Carmelo Anthony
# 3       Reggie Jackson            Victor Oladipo         TJ Warren
# 4        Stephen Curry         Langston Galloway   Carmelo Anthony
# ..                 ...                       ...               ...
# 196  Russell Westbrook             Klay Thompson    Andre Iguodala
# 197       Kyrie Irving             DeMar DeRozan      LeBron James
# 198  Russell Westbrook            Andre Roberson      Kevin Durant
# 199         Kyle Lowry             Iman Shumpert      LeBron James
# 200      Stephen Curry             Klay Thompson   Harrison Barnes
#
#                    PF                    C                  G  \
# 0      Ersan Ilyasova       Andre Drummond      Stephen Curry
# 1         Greg Monroe        Jahlil Okafor        CJ McCollum
# 2       Blake Griffin           Al Horford        Kyle Korver
# 3    Anthony Tolliver   Karl-Anthony Towns  Russell Westbrook
# 4         Drew Gooden  Willie Cauley-Stein        Mike Conley
# ..                ...                  ...                ...
# 196       Serge Ibaka         Festus Ezeli       Dion Waiters
# 197        Kevin Love       Timofey Mozgov           JR Smith
# 198       Serge Ibaka    Marreese Speights       Dion Waiters
# 199        Kevin Love      Bismack Biyombo           JR Smith
# 200    Draymond Green         Andrew Bogut     Andre Roberson
#
#                     F               UTIL      Date  Salary    FPTS
# 0       Marcus Morris       LeBron James  20151027   49800  322.50
# 1       Kawhi Leonard  Jonas Valanciunas  20151028   49800  372.50
# 2         Kyle OQuinn       John Jenkins  20151029   47900  287.00
# 3       Marcus Morris         Kevin Love  20151030   49600  379.25
# 4            Rudy Gay     Brandon Knight  20151031   49600  355.00
# ..                ...                ...       ...     ...     ...
# 196      Kevin Durant     Andre Roberson  20160524   49500  312.25
# 197  Tristan Thompson  Richard Jefferson  20160525   47900  233.25
# 198    Draymond Green       Andrew Bogut  20160526   49800  284.75
# 199     James Johnson       Kyrie Irving  20160527   49900  262.25
# 200       Serge Ibaka     Andre Iguodala  20160528   49700  282.50
#
# [201 rows x 11 columns]

# %%
dates=soln_df.Date.unique()
len(dates)
# Out:
# 201

# %%
# double checking that the dataframe has correct FPTS and Salary info
# and only consists of valid lineups

for x in range(len(dates)):
  date = dates[x]
  print(date)
  currentPlayers = df2[df2['Date']==date]

  # get the list of players for the specific date
  l1 = buildPositionDFs(currentPlayers, positions)

  # get the soln for the specific date
  geneticSoln = soln_df[soln_df['Date']==date].squeeze()

  lineup = geneticSoln[['PG', 'SG', 'SF', 'PF', 'C', 'G', 'F', 'UTIL']].to_dict()

  # check each player is in the correct position
  for i in range(8):
    pos = positions[i]
    pos_df = l1[i]
    player = lineup[pos]

    # print(player, pos_df['Name'].to_list())
    if not pos_df['Name'].str.contains(player).any():
      raise ValueError(f'Date: {date}\tPlayer missing {player}')


  soln_sal = geneticSoln['Salary']
  soln_score = geneticSoln['FPTS']
  # print(lineup)

  salary = getSalary(lineup)
  score = getScore(lineup)

  # print(soln_sal, salary)
  # print(soln_score, score)

  if (salary > 50000):
    raise ValueError(f'Date: {date}\tSalary > 50000: {salary}')

  if (salary != soln_sal):
    raise ValueError(f'Date: {date}\tSalaries not matching: {soln_sal},{salary}')

  if (score != soln_score):
    raise ValueError(f'Date: {date}\tScores not matching: {soln_score},{score}')
# Out:
# 20151027
# 20151028
# 20151029
# 20151030
# 20151031
# 20151101
# 20151102
# 20151103
# 20151104
# 20151105
# 20151106
# 20151107
# 20151108
# 20151109
# 20151110
# 20151111
# 20151112
# 20151113
# 20151114
# 20151115
# 20151116
# 20151117
# 20151118
# 20151119
# 20151120
# 20151121
# 20151122
# 20151123
# 20151124
# 20151125
# 20151127
# 20151128
# 20151129
# 20151130
# 20151201
# 20151202
# 20151203
# 20151204
# 20151205
# 20151206
# 20151207
# 20151208
# 20151209
# 20151210
# 20151211
# 20151212
# 20151213
# 20151214
# 20151215
# 20151216
# 20151217
# 20151218
# 20151219
# 20151220
# 20151221
# 20151222
# 20151223
# 20151225
# 20151226
# 20151227
# 20151228
# 20151229
# 20151230
# 20151231
# 20160101
# 20160102
# 20160103
# 20160104
# 20160105
# 20160106
# 20160107
# 20160108
# 20160109
# 20160110
# 20160111
# 20160112
# 20160113
# 20160114
# 20160115
# 20160116
# 20160117
# 20160118
# 20160119
# 20160120
# 20160121
# 20160122
# 20160123
# 20160124
# 20160125
# 20160126
# 20160127
# 20160128
# 20160129
# 20160130
# 20160131
# 20160201
# 20160202
# 20160203
# 20160204
# 20160205
# 20160206
# 20160207
# 20160208
# 20160209
# 20160210
# 20160211
# 20160218
# 20160219
# 20160220
# 20160221
# 20160222
# 20160223
# 20160224
# 20160225
# 20160226
# 20160227
# 20160228
# 20160229
# 20160301
# 20160302
# 20160303
# 20160304
# 20160305
# 20160306
# 20160307
# 20160308
# 20160309
# 20160310
# 20160311
# 20160312
# 20160313
# 20160314
# 20160315
# 20160316
# 20160317
# 20160318
# 20160319
# 20160320
# 20160321
# 20160322
# 20160323
# 20160324
# 20160325
# 20160326
# 20160327
# 20160328
# 20160329
# 20160330
# 20160331
# 20160401
# 20160402
# 20160403
# 20160405
# 20160406
# 20160407
# 20160408
# 20160409
# 20160410
# 20160411
# 20160412
# 20160413
# 20160416
# 20160417
# 20160418
# 20160419
# 20160420
# 20160421
# 20160422
# 20160423
# 20160424
# 20160425
# 20160426
# 20160427
# 20160428
# 20160429
# 20160501
# 20160502
# 20160503
# 20160504
# 20160505
# 20160506
# 20160507
# 20160508
# 20160509
# 20160510
# 20160511
# 20160512
# 20160513
# 20160515
# 20160516
# 20160517
# 20160518
# 20160519
# 20160521
# 20160522
# 20160523
# 20160524
# 20160525
# 20160526
# 20160527
# 20160528

# %% [markdown]
# # Thesis Defense Examples

# %% [markdown]
# Mutation Example

# %%
lineup1 = population[5].copy()
lineup1

# %%
mut_lineup1 = mutate(lineup1, mutation_rate, l1, param)
mut_lineup1
# Out:
# [{'PG': 'Coby White',
#   'SG': 'Rodney Hood',
#   'SF': 'Thaddeus Young',
#   'PF': 'Meyers Leonard',
#   'C': 'Andre Drummond',
#   'G': 'Jeremy Lamb',
#   'F': 'Davis Bertans',
#   'UTIL': 'KZ Okpala'},
#  36800,
#  198.5,
#  198.5]

# %%
for pos in mut_lineup1[0]:
  print(getPlayer(df, dates[1], mut_lineup1[0][pos]))

# %% [markdown]
# Crossover Example
